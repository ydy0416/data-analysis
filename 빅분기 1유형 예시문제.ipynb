# %%
# mtcars 데이터셋(mtcars.csv)의 qsec 컬럼을 최소 최대 척도(min-max scale)로 변환한 후 0.5보다 큰 값을 가지는 레코드 수를 구하시오.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/dataq/main/mtcars.csv',index_col=0)

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
X=df['qsec']
X_MinMax=(X-X.min(axis=0))/(X.max(axis=0)-X.min(axis=0))
overNum=len(X_MinMax[X_MinMax>0.5])

# %%
X.min(axis=0)
# Out:
# 14.5

# %%
X_MinMax.values
# Out:
# array([0.23333333, 0.3       , 0.48928571, 0.58809524, 0.3       ,
#        0.68095238, 0.15952381, 0.6547619 , 1.        , 0.45238095,
#        0.52380952, 0.3452381 , 0.36904762, 0.41666667, 0.41428571,
#        0.3952381 , 0.34761905, 0.59166667, 0.47857143, 0.64285714,
#        0.65595238, 0.28214286, 0.33333333, 0.10833333, 0.30357143,
#        0.52380952, 0.26190476, 0.28571429, 0.        , 0.11904762,
#        0.01190476, 0.48809524])

# %%
overNum
# Out:
# 9

# %%
df.qsec.mean()
# Out:
# 17.848750000000003

# %%
X.mean(axis=0)
# Out:
# 17.848750000000003

# %%
df.qsec.std()
# Out:
# 1.7869432360968431

# %%
X.std(axis=0)
# Out:
# 1.7869432360968431

# %%
X=df['qsec']
X_scale=(X-X.mean(axis=0))/X.std(axis=0)
print(X_scale.max())
print(X_scale.min())
# Out:
# 2.826754592962484
# -1.8740102832334835

# %%
import numpy as np

# %%
iqr=df['wt'].quantile(0.75)-df['wt'].quantile(0.25)
low=df['wt'].quantile(0.25)-1.5*iqr
high=df['wt'].quantile(0.75)+1.5*iqr
df.wt[(df.wt<low)|(df.wt>high)].values
# Out:
# array([5.25 , 5.424, 5.345])

# %%
df.corr()[['mpg']][1:].sort_values('mpg', ascending=False)
# Out:
#            mpg
# drat  0.681172
# vs    0.664039
# am    0.599832
# gear  0.480285
# qsec  0.418684
# carb -0.550925
# hp   -0.776168
# disp -0.847551
# cyl  -0.852162
# wt   -0.867659

# %%
dataUrl ='https://raw.githubusercontent.com/Datamanim/video/master/video_games_sale.csv'

# %%
df=pd.read_csv(dataUrl, index_col=0)
df
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 0                            Wii Sports      Wii           2006.0    Sports
# 1                        Mario Kart Wii      Wii           2008.0    Racing
# 2                     Wii Sports Resort      Wii           2009.0    Sports
# 3                 New Super Mario Bros.       DS           2006.0  Platform
# 4                              Wii Play      Wii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 6820         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 6821     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
df['year_of_ten']=df['Year_of_Release']-df['Year_of_Release']%10

# %%
max=df['year_of_ten'].max()
min=df['year_of_ten'].min()
print('max : %d'%max, end=' ')
print('min : %d'%min)
# Out:
# max : 2010 min : 1980

# %%
len(df.loc[df.Platform.isin(['PS','PS2', 'PS3', 'PS4', 'PSV'])&(df.Genre=='Action')])
# Out:
# 616

# %%
over_platfromName = df.Platform.value_counts()[df.Platform.value_counts()>=400].index

# %%
df.loc[df.Platform.isin(over_platfromName)].groupby('Platform')['User_Score'].mean().sort_values(ascending=False).to_frame()
# Out:
#           User_Score
# Platform
# PS2         7.664386
# XB          7.540708
# PC          7.060369
# DS          7.047198
# Wii         6.903758
# PS3         6.782705
# X360        6.780769

# %%
df
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 0                            Wii Sports      Wii           2006.0    Sports
# 1                        Mario Kart Wii      Wii           2008.0    Racing
# 2                     Wii Sports Resort      Wii           2009.0    Sports
# 3                 New Super Mario Bros.       DS           2006.0  Platform
# 4                              Wii Play      Wii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 6820         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 6821     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
target=df[df['Name'].str.contains('Mario')].Developer.value_counts()
target==3
# Out:
# Nintendo                                                        False
# Camelot Software Planning                                       False
# Hudson                                                          False
# Intelligent Systems                                             False
# Nintendo, Nintendo Software Technology                           True
# Nintendo, Nd Cube                                                True
# Hudson Soft                                                     False
# Next Level Games                                                False
# Square Enix                                                     False
# Namco Bandai Games                                              False
# Fuse Games Limited                                              False
# Retro Studios, Entertainment Analysis & Development Division    False
# Nintendo EAD Tokyo                                              False
# ...

# %%
df[df['Platform']=='PS2'].User_Score.kurtosis()
# Out:
# 2.4920035946875965

# %%
df
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 0                            Wii Sports      Wii           2006.0    Sports
# 1                        Mario Kart Wii      Wii           2008.0    Racing
# 2                     Wii Sports Resort      Wii           2009.0    Sports
# 3                 New Super Mario Bros.       DS           2006.0  Platform
# 4                              Wii Play      Wii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 6820         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 6821     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
len(df[(df['NA_Sales']+df['EU_Sales']+df['JP_Sales']+df['Other_Sales'])!=df['Global_Sales']])
# Out:
# 3636

# %%
len(df[(df['User_Count']>=120)&(df['User_Score']>=9.0)])
# Out:
# 86

# %%
from sklearn.preprocessing import RobustScaler

# %%
dir(sklearn.preprocessing)
# Out:
# ['Binarizer',
#  'FunctionTransformer',
#  'KBinsDiscretizer',
#  'KernelCenterer',
#  'LabelBinarizer',
#  'LabelEncoder',
#  'MaxAbsScaler',
#  'MinMaxScaler',
#  'MultiLabelBinarizer',
#  'Normalizer',
#  'OneHotEncoder',
#  'OrdinalEncoder',
#  'PolynomialFeatures',
#  'PowerTransformer',
#  'QuantileTransformer',
#  'RobustScaler',
#  'StandardScaler',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_csr_polynomial_expansion',
#  '_data',
#  '_discretization',
#  '_encoders',
#  '_function_transformer',
#  '_label',
#  'add_dummy_feature',
#  'binarize',
#  'label_binarize',
#  'maxabs_scale',
#  'minmax_scale',
#  'normalize',
#  'power_transform',
#  'quantile_transform',
#  'robust_scale',
#  'scale']

# %%
help(RobustScaler)
# Out:
# Help on class RobustScaler in module sklearn.preprocessing._data:
#
# class RobustScaler(sklearn.base.TransformerMixin, sklearn.base.BaseEstimator)
#  |  RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), copy=True)
#  |
#  |  Scale features using statistics that are robust to outliers.
#  |
#  |  This Scaler removes the median and scales the data according to
#  |  the quantile range (defaults to IQR: Interquartile Range).
#  |  The IQR is the range between the 1st quartile (25th quantile)
#  |  and the 3rd quartile (75th quantile).
#  |
#  |  Centering and scaling happen independently on each feature by
#  |  computing the relevant statistics on the samples in the training
#  |  set. Median and interquartile range are then stored to be used on
#  |  later data using the ``transform`` method.
#  |
#  |  Standardization of a dataset is a common requirement for many
#  |  machine learning estimators. Typically this is done by removing the mean
# ...

# %%
transformer=RobustScaler()

# %%
transformer.transform(df['Global_Sales'])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-135-6c193ac449f3> in <module>
# ----> 1 transformer.transform(df['Global_Sales'])
#
# C:\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#    1245             The data used to scale along the specified axis.
#    1246         """
# -> 1247         check_is_fitted(self)
#    1248         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#    1249                         estimator=self, dtype=FLOAT_DTYPES,
#
# C:\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
#     966     if not attrs:
# --> 967         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     968
#     969
#
# ...

# %%
df['Global_Sales']
# Out:
# 0       82.53
# 1       35.52
# 2       32.77
# 3       29.80
# 4       28.92
#         ...
# 6820     0.01
# 6821     0.01
# 6822     0.01
# 6823     0.01
# 6824     0.01
# Name: Global_Sales, Length: 6825, dtype: float64
